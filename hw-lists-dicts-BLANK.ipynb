# %% [markdown]
# # Lists, Dicts & Read
#
# The goal for this homework is to see the relevant journalistic uses for what we covered in class.
#
# 1. Creating lists
# 2. Building dictionaries
# 3. Ingest a dataset

# %% [markdown]
# ## Creating Lists
#
# You've <a href="https://apps.health.ny.gov/pubdoh/professionals/doctors/conduct/factions/AllRecordsAction.action?">scraped thousands of documents</a> that contain disciplinary actions against doctors in New York state. You compile key words and phrases that will target certain types of violations. These include:
#
# - improper touching
# - self-medication
# - self-prescribing
# - opioid addiction
# - harassment
# - coercion
# - sexual harrassment
# - sex
# - sexual favor
# - abuse of trust
# - opioid prescriptions in return for sex
#
# Create a list called ```search_terms``` that holds the search terms above.

# %%
search_terms = ["improper touching", "self-medication", "self-prescribing", "opioid addiction", "harassment", "coercion", "sexual harrassment", "sex", "sexual favor", "abuse of trust", "opioid prescriptions in return for sex"]
search_terms
# Out:
# ['improper touching',
#  'self-medication',
#  'self-prescribing',
#  'opioid addiction',
#  'harassment',
#  'coercion',
#  'sexual harrassment',
#  'sex',
#  'sexual favor',
#  'abuse of trust',
#  'opioid prescriptions in return for sex']

# %%
## What type of a data object is ```search_term```

type(search_terms)
# Out:
# list

# %%
## How long is this list?

len(search_terms)
# Out:
# 11

# %% [markdown]
# ### Building dictionaries
#
# Create a list of dictionaries called "donations" using the content from the image below:
#
# <img src="https://sandeepmj.github.io/image-host/donors.png">
#
# ## If you want to copy and paste the content, click <a href="https://docs.google.com/spreadsheets/d/17JBUMJpAiMz5WavglaE3HLHijRxHHJUd/edit?usp=sharing&ouid=107646296031550187966&rtpof=true&sd=true" target="blank">here</a> to download the Excel file.
#
#
# You may copy and paste the contents of each cell in the XLSX file, but type out all the code required to build the list of dictionaries.

# %%
## Building dictionaries for each donation.

donation_1 = {"Year":"2017", "Donor":"David H Koch Charitable Foundation", "Grantee":"City Center For Music And Drama", "Amount":15_000_000} 
donation_2 = {"Year":"2013", "Donor":"Bradley Impact Fund Inc", "Grantee":"Young Americas Foundation", "Amount":11_000} 
donation_3 = {"Year":"2016", "Donor":"Mercer Family Foundation", "Grantee":"The Becket Fund", "Amount":250_000} 
donation_4 = {"Year":"2012", "Donor":"Charles Koch Foundation", "Grantee":"The Phillips Foundation", "Amount":25_000} 
donation_5 = {"Year":"2017", "Donor":"Barbara And Barre Seid Foundation", "Grantee":"Boys Scouts of America", "Amount":2_634_600}

# %%
## Building a list that contains each donation entry.

donations = (donation_1, donation_2, donation_3, donation_4, donation_5)

# %%
## Calling donations.

donations
# Out:
# ({'Year': '2017',
#   'Donor': 'David H Koch Charitable Foundation',
#   'Grantee': 'City Center For Music And Drama',
#   'Amount': 15000000},
#  {'Year': '2013',
#   'Donor': 'Bradley Impact Fund Inc',
#   'Grantee': 'Young Americas Foundation',
#   'Amount': 11000},
#  {'Year': '2016',
#   'Donor': 'Mercer Family Foundation',
#   'Grantee': 'The Becket Fund',
#   'Amount': 250000},
#  {'Year': '2012',
#   'Donor': 'Charles Koch Foundation',
#   'Grantee': 'The Phillips Foundation',
#   'Amount': 25000},
#  {'Year': '2017',
#   'Donor': 'Barbara And Barre Seid Foundation',
#   'Grantee': 'Boys Scouts of America',
#   'Amount': 2634600})

# %%
## Printing donations.

print(donations)
# Out:
# ({'Year': '2017', 'Donor': 'David H Koch Charitable Foundation', 'Grantee': 'City Center For Music And Drama', 'Amount': 15000000}, {'Year': '2013', 'Donor': 'Bradley Impact Fund Inc', 'Grantee': 'Young Americas Foundation', 'Amount': 11000}, {'Year': '2016', 'Donor': 'Mercer Family Foundation', 'Grantee': 'The Becket Fund', 'Amount': 250000}, {'Year': '2012', 'Donor': 'Charles Koch Foundation', 'Grantee': 'The Phillips Foundation', 'Amount': 25000}, {'Year': '2017', 'Donor': 'Barbara And Barre Seid Foundation', 'Grantee': 'Boys Scouts of America', 'Amount': 2634600})

# %% [markdown]
# #### Notice the difference between ```print()``` and ```calling```?

# %%
## How many items are in this list?
## Don't just manually count them.
## There will come a time when you will have thousands of items!

len(donations)
# Out:
# 5

# %% [markdown]
# ## Reading data
#
# Download this [sample dataset](https://drive.google.com/file/d/18bW5naPyYbm--nk1meOvTPBNg8gYLk7T/view?usp=sharing) and read it into this notebook.
#
# **Remember that you have to import the appropriate library before you can read the dataset into this notebook.**

# %%
## Importing pandas library.

import pandas as pd

# %%
## Importing dataset into a dataframe.

df = pd.read_csv('summons_sample.csv')

# %%
# Calling first five rows of dataframe to ensure it works properly.

df.head()
# Out:
#    SUMMONS_KEY SUMMONS_DATE           OFFENSE_DESCRIPTION LAW_SECTION_NUMBER  \
# 0    286197370   05/01/2024  ALCOHOLIC BEVERAGE IN PUBLIC         10-125(2B)
# 1    278254074   11/29/2023              RECKLESS DRIVING               1212
# 2    253581920   11/03/2022  ALCOHOLIC BEVERAGE IN PUBLIC         10-125(2B)
# 3    262113325   01/18/2023                       SMOKING               3209
# 4    272793060   08/13/2023  ALCOHOLIC BEVERAGE IN PUBLIC         10-125(2B)
#
#        LAW_DESCRIPTION SUMMONS_CATEGORY_TYPE AGE_GROUP SEX            RACE  \
# 0               (null)                (null)     25-44   M           BLACK
# 1                  VTL                   VTL     25-44   M  WHITE HISPANIC
# 2               (null)                (null)     25-44   M           BLACK
# 3  Education Law (NYS)         EDUCATION LAW     18-24   M           BLACK
# 4               (null)                (null)     25-44   M           BLACK
#
#    JURISDICTION_CODE      BORO  PRECINCT_OF_OCCUR  X_COORDINATE_CD  \
# 0                  0    QUEENS                101          1052603
# 1                  0     BRONX                 48          1013201
# 2                  0     BRONX                 47          1022835
# 3                  0  BROOKLYN                 73          1008495
# 4                  0  BROOKLYN                 81          1004979
#
#    Y_COORDINATE_CD   Latitude  Longitude  \
# 0           159209  40.603406 -73.753843
# 1           247704  40.846518 -73.895360
# 2           262759  40.887802 -73.860452
# 3           183171  40.669406 -73.912602
# 4           186690  40.679073 -73.925265
#
#                                         Lon_Lat
# 0                  POINT (-73.753843 40.603406)
# 1   POINT (-73.8953596088657 40.84651784820482)
# 2              POINT (-73.86045187 40.88780234)
# 3              POINT (-73.91260166 40.66940558)
# 4  POINT (-73.92526530591317 40.67907337559362)
